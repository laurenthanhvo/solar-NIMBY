# %%
import pandas as pd
import numpy as np
import geopandas as gpd

RAW_DATA_PATH = "../../data/"
shapefile = "" # path to shapefile (Too large so not in repo)

# %%
bg_bb = gpd.read_file(f"{RAW_DATA_PATH}block_group_raw/{shapefile}") # Not in repo due to size
bg_bb.head()
# Out:
#   STATEFP COUNTYFP TRACTCE BLKGRPCE                GEOIDFQ         GEOID NAME  \
# 0      01      113  030300        1  1500000US011130303001  011130303001    1
# 1      04      015  953406        2  1500000US040159534062  040159534062    2
# 2      04      001  945002        1  1500000US040019450021  040019450021    1
# 3      04      027  000301        2  1500000US040270003012  040270003012    2
# 4      05      007  020803        3  1500000US050070208033  050070208033    3
#
#         NAMELSAD LSAD      ALAND    AWATER  \
# 0  Block Group 1   BG     829037         0
# 1  Block Group 2   BG  577144904  15330641
# 2  Block Group 1   BG  607817889    362533
# 3  Block Group 2   BG    2041298     71837
# 4  Block Group 3   BG    3545865     53379
#
#                                             geometry
# 0  POLYGON ((-85.00365 32.47885, -85.00133 32.480...
# 1  POLYGON ((-114.32649 34.43788, -114.31824 34.4...
# 2  POLYGON ((-109.32335 35.54182, -109.31495 35.5...
# 3  POLYGON ((-114.66727 32.72505, -114.66541 32.7...
# 4  POLYGON ((-94.27908 36.48882, -94.27656 36.491...

# %%
county_bounding_boxes_FIPS = pd.read_csv(f"{RAW_DATA_PATH}extras/US_FIPS_Codes.csv")

states_to_drop = ['American Samoa', 'Puerto Rico', 'Alaska', 'Hawaii', 'Commonwealth of the Northern Mariana Islands', 'United States Virgin Islands', 'Guam']

# Columns names in the first row
county_bounding_boxes_FIPS.columns = county_bounding_boxes_FIPS.iloc[0]
county_bounding_boxes_FIPS = county_bounding_boxes_FIPS[1:]
county_bounding_boxes_FIPS = county_bounding_boxes_FIPS.iloc[:, :-1]

county_bounding_boxes_FIPS = county_bounding_boxes_FIPS[~county_bounding_boxes_FIPS['State'].isin(states_to_drop)]

county_bounding_boxes_FIPS.head()
# Out:
# 0    State County Name FIPS State FIPS County
# 1  Alabama     Autauga         01         001
# 2  Alabama     Baldwin         01         003
# 3  Alabama     Barbour         01         005
# 4  Alabama        Bibb         01         007
# 5  Alabama      Blount         01         009

# %%
merged = pd.merge(bg_bb, county_bounding_boxes_FIPS, left_on=['STATEFP', 'COUNTYFP'], right_on=['FIPS State', 'FIPS County'], how='inner').drop(columns=['FIPS State', 'FIPS County'])
merged.head()
# Out:
#   STATEFP COUNTYFP TRACTCE BLKGRPCE                GEOIDFQ         GEOID NAME  \
# 0      01      113  030300        1  1500000US011130303001  011130303001    1
# 1      01      113  031200        1  1500000US011130312001  011130312001    1
# 2      01      113  030403        2  1500000US011130304032  011130304032    2
# 3      01      113  030500        2  1500000US011130305002  011130305002    2
# 4      01      113  030601        1  1500000US011130306011  011130306011    1
#
#         NAMELSAD LSAD      ALAND  AWATER  \
# 0  Block Group 1   BG     829037       0
# 1  Block Group 1   BG  252578677  909711
# 2  Block Group 2   BG     840428       0
# 3  Block Group 2   BG    1457772       0
# 4  Block Group 1   BG    2692957    6893
#
#                                             geometry    State County Name
# 0  POLYGON ((-85.00365 32.47885, -85.00133 32.480...  Alabama     Russell
# 1  POLYGON ((-85.31136 32.35557, -85.30299 32.377...  Alabama     Russell
# 2  POLYGON ((-85.03047 32.49030, -85.02532 32.492...  Alabama     Russell
# 3  POLYGON ((-85.03723 32.49351, -85.03429 32.493...  Alabama     Russell
# 4  POLYGON ((-85.03005 32.43032, -85.02710 32.432...  Alabama     Russell

# %%
# check for duplicates
print(merged.shape)

# check using GEOID
print(merged['GEOID'].nunique())
# Out:
# (235092, 14)
# 235092

# %% [markdown]
# ## Calculate the area of each bg polygon

# %%
merged['area km2'] = merged['geometry'].to_crs(epsg=5070).map(lambda p: p.area / 10**6)
merged['area mi2'] = merged['geometry'].to_crs(epsg=5070).map(lambda p: p.area / 10**6 * 0.386102)
merged.head()
# Out:
#   STATEFP COUNTYFP TRACTCE BLKGRPCE                GEOIDFQ         GEOID NAME  \
# 0      01      113  030300        1  1500000US011130303001  011130303001    1
# 1      01      113  031200        1  1500000US011130312001  011130312001    1
# 2      01      113  030403        2  1500000US011130304032  011130304032    2
# 3      01      113  030500        2  1500000US011130305002  011130305002    2
# 4      01      113  030601        1  1500000US011130306011  011130306011    1
#
#         NAMELSAD LSAD      ALAND  AWATER  \
# 0  Block Group 1   BG     829037       0
# 1  Block Group 1   BG  252578677  909711
# 2  Block Group 2   BG     840428       0
# 3  Block Group 2   BG    1457772       0
# 4  Block Group 1   BG    2692957    6893
#
#                                             geometry    State County Name  \
# 0  POLYGON ((-85.00365 32.47885, -85.00133 32.480...  Alabama     Russell
# 1  POLYGON ((-85.31136 32.35557, -85.30299 32.377...  Alabama     Russell
# 2  POLYGON ((-85.03047 32.49030, -85.02532 32.492...  Alabama     Russell
# 3  POLYGON ((-85.03723 32.49351, -85.03429 32.493...  Alabama     Russell
# 4  POLYGON ((-85.03005 32.43032, -85.02710 32.432...  Alabama     Russell
#
#      area km2   area mi2
# 0    0.802873   0.309991
# 1  253.475811  97.867518
# 2    0.842279   0.325205
# 3    1.459928   0.563681
# 4    2.682887   1.035868

# %%
bounding_box_bg = merged[['GEOID', 'STATEFP', 'COUNTYFP', 'TRACTCE', 'BLKGRPCE', 'State', 'County Name', 'area km2', 'area mi2']]
bounding_box_bg.head()
# Out:
#           GEOID STATEFP COUNTYFP TRACTCE BLKGRPCE    State County Name  \
# 0  011130303001      01      113  030300        1  Alabama     Russell
# 1  011130312001      01      113  031200        1  Alabama     Russell
# 2  011130304032      01      113  030403        2  Alabama     Russell
# 3  011130305002      01      113  030500        2  Alabama     Russell
# 4  011130306011      01      113  030601        1  Alabama     Russell
#
#      area km2   area mi2
# 0    0.802873   0.309991
# 1  253.475811  97.867518
# 2    0.842279   0.325205
# 3    1.459928   0.563681
# 4    2.682887   1.035868

# %%
bounding_box_bg.to_csv(f"{RAW_DATA_PATH}block_group_clean/bounding_box_full_bg.csv", index=False)
